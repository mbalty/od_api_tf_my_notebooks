# %%
from azure.storage import CloudStorageAccount
import os
import json
import pickle
import requests
import random
import shutil
import numpy as np
from PIL import Image

# %% [markdown]
# Login to Azure account and create the blob service

# %%
storage_account = CloudStorageAccount(account_name='whizcartcentral', account_key='/0gR3pmzy8H0Adv+Uklct8eQxA8esJ63DhqA40QfQkHT3Dnru25A9xGmGp/U50jaE4LmI/kQDDUDz6CZsvNj7A==')

# %%
blob_service = storage_account.create_block_blob_service()

# %%
container_images = 'cartimages'

# %%
interesing_sessions = list()

# %%
# for session in range(160000, 165000):
#     generator = blob_service.list_blobs(container_images, prefix="ecenter_porta/"+str(session))
#     count = 0
#     for blob in generator:
#         if blob.name.endswith(".jpg") and "TOP_FRONT" in blob.name:
#             count += 1
    
#     if count > 0:
#         interesing_sessions.append((session, count))
#         print (session, count)

# %%
interesing_sessions = pickle.load(open("/home/wc-gpu/storage4tb/session_data_thesis/sessions160000_165000.pkl", "rb"))

# %%
interesing_sessions = sorted(interesing_sessions, key=lambda a: -a[1])

# %%
count = 0
i = 0
while count < 50000:
    sess, c = interesing_sessions[i]
    count += c 
    i+=1
print (i)

# %%
save_sessions = sorted(interesing_sessions[:i], key=lambda a: a[1])

# %%
download_folder = "/home/wc-gpu/storage4tb/session_data_thesis/sessions160000_165000"

# %%
progress = 0
for session, c in save_sessions:
    generator = blob_service.list_blobs(container_images, prefix="ecenter_porta/"+str(session))
    if not os.path.exists(os.path.join(download_folder, str(session))):     
        os.makedirs(os.path.join(download_folder, str(session)))
    
    blobs = []
    for blob in generator:
        if blob.name.endswith(".jpg") and "TOP_FRONT" in blob.name:
            try:
                blob_service.get_blob_to_path(container_images, blob.name, os.path.join(download_folder, str(session), 
                                                                                "_".join(blob.name.split("/"))))
                blobs.append(blob.name)
            except Exception as ex:
                print("exception", blob.name)

            print ("progress", session, progress / count, end="\r")
            progress += 1
    
    if not os.path.exists(os.path.join(download_folder, "sample")):     
        os.makedirs(os.path.join(download_folder, "sample"))
    sample_blob = random.choice(blobs)
    blob_service.get_blob_to_path(container_images, sample_blob, os.path.join(download_folder, "sample", str(session) + ".jpg"))

# %%
filter_sessions = ['161584',
 '163422',
 '160881',
 '163378',
 '161209',
 '160665',
 '163185',
 '161792',
 '160329',
 '161745',
 '161023',
 '161779',
 '163797',
 '161802',
 '163754',
 '162847',
 '163542',
 '162884',
 '163224',
 '161369',
 '162661',
 '160704',
 '164204',
 '162675',
 '160738',
 '161426',
 '163557',
 '162649',
 '162463',
 '161630',
 '161156',
 '163033',
 '161817',
 '161195',
 '164172',
 '161022',
 '163812',
 '161787',
 '160670',
 '161220',
 '163437',
 '160894',
 '161552',
 '162932',
 '162926',
 '161587',
 '160699',
 '162924',
 '161593',
 '161544',
 '163421',
 '161550',
 '161578',
 '164372',
 '162298',
 '161949',
 '163151',
 '161034',
 '163179',
 '160316',
 '161197',
 '161829',
 '161632',
 '160538',
 '162449',
 '164004',
 '162475',
 '160935',
 '163952',
 '161823',
 '161604',
 '163761',
 '161176',
 '160903',
 '163211',
 '161360',
 '161374',
 '162655',
 '164224',
 '164230',
 '162127',
 '160725',
 '160719',
 '162873',
 '160241',
 '162318',
 '161611',
 '161188',
 '161995',
 '161017',
 '162720',
 '160679',
 '163402',
 '160686',
 '160692',
 '162907',
 '162911',
 '164384',
 '162939',
 '160848',
 '160690',
 '163399',
 '163414',
 '163366',
 '161559',
 '163428',
 '162722',
 '160653',
 '162285',
 '161001',
 '163602',
 '160445',
 '164031',
 '164025',
 '162454',
 '162871',
 '162859',
 '163206',
 '162118',
 '161377',
 '162124',
 '162642',
 '164233',
 '163548',
 '162657',
 '163575',
 '163213',
 '161376',
 '160929',
 '162680',
 '162858',
 '162870',
 '160901',
 '160915',
 '164030',
 '163039',
 '161160',
 '161612',
 '161821',
 '161000',
 '163171',
 '161766',
 '163830',
 '161799',
 '161558',
 '162737',
 '163429',
 '164346',
 '163401',
 '163398',
 '160685',
 '163388',
 '162082',
 '162914',
 '160124',
 '162727',
 '163363',
 '163834',
 '164140',
 '164154',
 '161992',
 '161004',
 '161010',
 '164168',
 '161776',
 '160534',
 '164020',
 '163767',
 '162479',
 '161602',
 '160087',
 '162860',
 '160905',
 '160736',
 '160722',
 '160044',
 '162109',
 '161366',
 '162652',
 '161159',
 '162487',
 '162518',
 '160333',
 '164155',
 '162524',
 '164141',
 '162530',
 '160327',
 '162281',
 '161561',
 '161549',
 '160864',
 '162929',
 '160899',
 '161239',
 '162718',
 '164194',
 '161749',
 '162526',
 '161985',
 '163176',
 '161826',
 '161198',
 '160279',
 '162693',
 '162650',
 '162644',
 '160053',
 '163214',
 '163566',
 '160708',
 '162889',
 '162651',
 '160913',
 '162686',
 '162447',
 '163759',
 '163995',
 '164022',
 '162490',
 '161006',
 '161760',
 '164142',
 '162255',
 '161990',
 '160330',
 '163822',
 '162725',
 '160867']

# %%
filter_sessions = set(filter_sessions)

# %%
rm_dir = os.path.join(download_folder, "deleted")
os.makedirs(rm_dir)

# %%
for session in os.listdir(download_folder):
    if session not in filter_sessions:
        try:
            a = int(session)
            shutil.move(os.path.join(download_folder, session), os.path.join(rm_dir, session))
            print ("moved ", session)
        except:
            continue

# %%
ann_folder = "/home/wc-gpu/storage4tb/session_data_thesis/annotations"

# %%
for ann_name in os.listdir(ann_folder):
    session = ann_name.split("_")[2]
    ann_session_folder = os.path.join(download_folder, session, "annotations")
    if not os.path.exists(ann_session_folder):
        os.makedirs(ann_session_folder)
    
    if not os.path.exists(os.path.join(ann_session_folder, ann_name)):
        shutil.copy(os.path.join(ann_folder, ann_name), os.path.join(ann_session_folder, ann_name))

# %%
for sess in os.listdir(download_folder):
    for f in os.listdir(os.path.join(download_folder, sess)):
        if f.endswith("jpg"):
            I = np.asarray(Image.open(os.path.join(download_folder, sess, f)))
            if I.shape != (768, 1024, 3):
                print(I.shape, )

# %%
768/2
# Out:
# 384.0
